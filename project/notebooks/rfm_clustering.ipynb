# %% [markdown]
# # RFM Clustering
# Train and analyze customer segments using K-Means on RFM features.

# %%
from pathlib import Path
import sys
import pandas as pd
import matplotlib.pyplot as plt

PROJECT_ROOT = Path.cwd().parents[0]
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.feature_engineering import run_rfm_clustering

# %%
df = pd.read_csv(PROJECT_ROOT / 'data' / 'processed_online_retail_II.csv')
segments, artifacts = run_rfm_clustering(df)
segments.head()

# %%
inertia = artifacts.inertia_by_k
plt.figure(figsize=(8, 5))
plt.plot(list(inertia.keys()), list(inertia.values()), marker='o')
plt.title('Elbow Method')
plt.xlabel('K')
plt.ylabel('Inertia')
plt.show()

# %%
segments['ClusterLabel'].value_counts()
