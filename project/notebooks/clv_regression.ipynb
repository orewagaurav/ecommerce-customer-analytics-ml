# %% [markdown]
# # CLV Regression
# Build and evaluate customer lifetime value prediction models.

# %%
from pathlib import Path
import sys
import pandas as pd

PROJECT_ROOT = Path.cwd().parents[0]
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.feature_engineering import build_clv_dataset
from src.train_models import _train_clv_model

# %%
df = pd.read_csv(PROJECT_ROOT / 'data' / 'processed_online_retail_II.csv')
clv_df = build_clv_dataset(df, horizon_days=90)
model, metrics, _ = _train_clv_model(clv_df)
metrics

# %%
clv_df[['CustomerID', 'FutureRevenue']].head()
